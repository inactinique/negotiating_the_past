# %% [markdown]
# # negotiating the past

# %% [markdown]
# We'll use ollama and llama3 7b to run some test.

# %% [markdown]
# We load the necessary libraries.

# %%
# !python --version
# %pip install umap-learn
# %pip install gensim
# %pip install nltk
# %pip install pandas
# %pip install anthropic
# %pip install ipywidgets

# %% [markdown]
# ## Creating a Historical Prompt Dataset with Claude

# %% [markdown]
# ## Import libraries and setup

# %%
# First cell - Import libraries and setup
import anthropic
import pandas as pd
import time
import logging
import os
from datetime import datetime
from tqdm.notebook import tqdm  # Note the use of tqdm.notebook for better display in Jupyter
from concurrent.futures import ThreadPoolExecutor
import json
import numpy as np

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f"past_reference_detection_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger("past_reference_detector")

# Create results directory
os.makedirs("results", exist_ok=True)

# %% [markdown]
# ## Load API key

# %%
# Second cell - Load API key securely
# Method 1: From a separate JSON file (recommended)
def load_api_key():
    try:
        # Try to load from config file
        with open('api_config.json') as f:
            config = json.load(f)
            return config.get('CLAUDE_API_KEY')
    except FileNotFoundError:
        # If file doesn't exist, check environment variables
        api_key = os.environ.get("CLAUDE_API_KEY")
        if api_key:
            return api_key
        else:
            # If not found, prompt user (only in notebook environment)
            from IPython.display import display
            from ipywidgets import widgets
            
            password = widgets.Password(
                description='Claude API Key:',
                style={'description_width': 'initial'},
                layout={'width': '50%'}
            )
            display(password)
            
            # This will allow the user to enter their API key securely
            # The entered key will be accessible via password.value in subsequent cells
            return None

# Create a JSON file for the API key that you won't commit to GitHub
# (Run this cell ONCE, then delete or comment it out)
"""
import json
with open('api_config.json', 'w') as f:
    json.dump({'CLAUDE_API_KEY': 'your_api_key_here'}, f)
    
print("Created api_config.json - add this file to .gitignore!")

# Create .gitignore if it doesn't exist
if not os.path.exists('.gitignore'):
    with open('.gitignore', 'w') as f:
        f.write("api_config.json\n.ipynb_checkpoints/\n__pycache__/\n*.pyc\nresults/\nlogs/\n")
    print("Created .gitignore file")
"""

# Load the API key
api_key = load_api_key()
if api_key and api_key.startswith("sk-"):
    print("✅ API key loaded successfully")
    # Initialize Claude client
    client = anthropic.Anthropic(api_key=api_key)
else:
    print("❌ API key not found or not valid format")
    # If using the widget approach, you'll need to get the value in the next cell
    # client = anthropic.Anthropic(api_key=password.value)
# Out:
# ✅ API key loaded successfully

# %% [markdown]
# ## Define your prompt

# %%
system_prompt = """As a panel of three historians with different specializations (international history, global history, and European history), analyze the following prompt to determine if it contains an implicit or explicit reference to the past.

Each historian should consider:

1. EXPLICIT REFERENCES: Clear temporal markers (yesterday, last week, previously), historical events, periods, or figures, or mentions of things that happened in the past.

2. IMPLICIT REFERENCES: Subtle indications of past time frames, comparative language suggesting change over time, or references to completed actions or states that are no longer current.

3. CONTEXTUAL CLUES: Words implying memory, reflection, or nostalgia; verbs in past tense that indicate historical events rather than hypotheticals.

4. DOMAIN-SPECIFIC PERSPECTIVES:
   - International historian: Look for references to international relations, treaties, wars, or cross-border interactions that occurred in the past
   - Global historian: Consider references to world systems, long-term global trends, or cross-cultural historical developments
   - European historian: Note references to European historical periods, events, or figures

After your individual analyses, debate any disagreements and reach a consensus.

Your final answer must be ONLY 'yes' or 'no' - nothing else.
"""

# %% [markdown]
# ## define functions

# %%
# Third cell - Helper functions
def analyze_prompt(prompt, client, retries=3, backoff_factor=2):
    """Analyze a single prompt using Claude API"""
    for attempt in range(retries):
        try:
            response = client.messages.create(
                model="claude-3-7-sonnet-20250219",
                max_tokens=10,
                temperature=0,
                system=system_prompt,
                messages=[
                    {"role": "user", "content": prompt}
                ]
            )
            
            # Extract the yes/no response
            classification = response.content[0].text.strip().lower()
            # Normalize the response
            if "yes" in classification:
                return "yes"
            else:
                return "no"
                
        except Exception as e:
            if attempt < retries - 1:
                sleep_time = backoff_factor ** attempt
                logger.warning(f"Error on prompt: {e}. Retrying in {sleep_time}s...")
                time.sleep(sleep_time)
            else:
                logger.error(f"Failed after {retries} attempts: {e}")
                return "error"

def process_batch(batch_prompts, client, batch_id):
    """Process a batch of prompts"""
    results = []
    for prompt in tqdm(batch_prompts, desc=f"Batch {batch_id}"):
        result = analyze_prompt(prompt, client)
        results.append({"prompt": prompt, "references_past": result})
    
    # Save batch results
    batch_df = pd.DataFrame(results)
    batch_df.to_csv(f"results/batch_{batch_id}_results.csv", index=False)
    logger.info(f"Completed batch {batch_id} with {len(results)} prompts")
    return results

# %% [markdown]
# ## Load your dataset

# %%
# Fourth cell - Load and explore dataset

# Method 1: load a sample
# Define the size of your sample
sample_size = 50000

# Determine the total number of rows in your dataset
total_rows = sum(1 for _ in open('data/prompts.csv')) - 1  # -1 for header

# Compute the probability of being selected for each line
skip_prob = 1 - sample_size / total_rows

# Use the skiprows parameter with a lambda function
prompts_df = pd.read_csv('data/prompts.csv', 
                      usecols=[0],  # First column only
                      skiprows=lambda x: x > 0 and np.random.random() < skip_prob)

# Convert the DataFrame to a list of prompts
prompts_list = prompts_df.iloc[:,0].tolist()

# Verify what we've created:
print(f"Number of prompts loaded: {len(prompts_list)}")
print("First 5 prompts:")
for i, prompt in enumerate(prompts_list[:5]):
    print(f"{i+1}. {prompt}")
# Out:
# Number of prompts loaded: 49368
# First 5 prompts:
# 1. Henry Cavill as Link in The Legend of Zelda Breath of the Wild promo shoot, studio lighting
# 2. emma watson holding the hand of jfk
# 3. hyper realistic photographer taking a picture, magical, gems, jewels, gold, steampunk, cyberpunk utopia, painted by tom bagshaw, mucha, gaston bussiere, craig mullins, j. c. leyendecker 8 k
# 4. A Dodo bird perched atop a Saguaro cactus in the desert, digital art, trending on Artstation, high detail, sharp focus, illustration, art by artgerm and greg rutkowski and alphonse mucha.
# 5. Bjork climbs out of your TV screen towards you like Sadako, J-Horror, 90s, 35mm film

# %% [markdown]
# ## Process a small test batch

# %%
# Fifth cell - Process a small test batch
# Test with a small batch first
test_batch = prompts_list[:5]  # Just 5 prompts for testing
test_results = process_batch(test_batch, client, "test")

# Display test results
test_df = pd.DataFrame(test_results)
display(test_df)

# Check if everything is working correctly
if len(test_df) == len(test_batch):
    print("✅ Test batch processed successfully!")
else:
    print("❌ Some issues with the test batch")
# Out:
# Batch test:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-05-07 12:40:25,880 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:26,731 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:27,408 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:28,440 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:29,446 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:29,454 - past_reference_detector - INFO - Completed batch test with 5 prompts
#                                               prompt references_past
# 0  Henry Cavill as Link in The Legend of Zelda Br...              no
# 1                emma watson holding the hand of jfk             yes
# 2  hyper realistic photographer taking a picture,...              no
# 3  A Dodo bird perched atop a Saguaro cactus in t...              no
# 4  Bjork climbs out of your TV screen towards you...             yes
# ✅ Test batch processed successfully!

# %% [markdown]
# ## Configure and start main processing with optimized parameters

# %%
# Sixth cell - Configure and start main processing
# Configuration for full run
batch_size = 50
max_workers = 1  # Adjust based on rate limits and resources

# Split dataset into batches
batches = [prompts_list[i:i+batch_size] for i in range(0, len(prompts_list), batch_size)]
print(f"Split dataset into {len(batches)} batches of size {batch_size}")

# Check for existing results to resume
existing_batches = set()
for filename in os.listdir("results"):
    if filename.startswith("batch_") and filename.endswith("_claude_results.csv"):
        try:
            batch_id = int(filename.split("_")[1])
            existing_batches.add(batch_id)
        except:
            pass

# Get batches to process
remaining_batches = [(i, batch) for i, batch in enumerate(batches) if i not in existing_batches]
print(f"Resume status: {len(batches)-len(remaining_batches)} batches already completed, {len(remaining_batches)} remaining")

# Cost estimate (approximate)
avg_tokens_per_prompt = 50  # Adjust based on your data
total_prompts = len(prompts_list)
estimated_tokens = total_prompts * (avg_tokens_per_prompt + 10)  # Input + output
estimated_cost = estimated_tokens / 1000 * 0.015  # Adjust rate based on current pricing

print(f"Estimated API cost: ${estimated_cost:.2f} (based on approx. ${0.015}/1K tokens)")
print(f"Processing {len(remaining_batches)} batches with {batch_size} prompts each using {max_workers} workers")

# Ask for confirmation before proceeding with the full run
from IPython.display import display
from ipywidgets import widgets

confirm = widgets.Button(
    description='Start Processing',
    button_style='success',
    tooltip='Click to start processing all batches'
)
cancel = widgets.Button(
    description='Cancel',
    button_style='danger',
    tooltip='Cancel processing'
)

output = widgets.Output()

display(widgets.HBox([confirm, cancel]), output)

def on_confirm(b):
    with output:
        print("Starting processing...")
        # The actual processing code will be in the next cell
        
def on_cancel(b):
    with output:
        print("Processing cancelled.")

confirm.on_click(on_confirm)
cancel.on_click(on_cancel)
# Out:
# Split dataset into 988 batches of size 50
# Resume status: 0 batches already completed, 988 remaining
# Estimated API cost: $44.43 (based on approx. $0.015/1K tokens)
# Processing 988 batches with 50 prompts each using 1 workers
# HBox(children=(Button(button_style='success', description='Start Processing', style=ButtonStyle(), tooltip='Cl…
# Output()

# %% [markdown]
# ## Execute processing (run after confirmation)

# %%
# Seventh cell - Execute processing (run after confirmation)
# Process batches with multiple threads
all_results = []

# Use tqdm to track overall progress
progress_bar = tqdm(total=len(remaining_batches), desc="Overall progress")

# Function to update progress
def update_progress(future):
    progress_bar.update(1)
    return future.result()

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = []
    for i, batch in remaining_batches:
        future = executor.submit(process_batch, batch, client, i)
        future.add_done_callback(update_progress)
        futures.append(future)
    
    # Wait for all futures to complete
    for future in futures:
        try:
            batch_results = future.result()
            all_results.extend(batch_results)
        except Exception as e:
            logger.error(f"Error processing batch: {e}")

progress_bar.close()
# Out:
# Overall progress:   0%|          | 0/988 [00:00<?, ?it/s]
# Batch 0:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:40:30,265 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:31,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:31,839 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:32,730 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:33,799 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:34,505 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:35,385 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:36,592 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:37,534 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:38,257 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:39,356 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:41,022 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:41,907 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:42,768 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:44,511 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:45,344 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:46,061 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:46,793 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:47,875 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:48,913 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:50,212 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:51,360 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:52,332 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:53,155 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:53,881 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:54,614 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:55,570 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:56,282 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:57,183 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:58,021 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:59,042 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:40:59,863 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:01,609 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:02,635 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:03,647 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:05,160 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:06,017 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:06,952 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:07,636 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:08,632 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:09,702 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:11,267 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:12,045 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:12,773 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:13,704 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:14,723 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:16,359 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:17,373 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:18,644 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:19,950 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:19,955 - past_reference_detector - INFO - Completed batch 0 with 50 prompts
# Batch 1:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:41:20,752 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:21,466 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:22,211 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:22,906 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:23,588 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:24,367 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:25,786 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:26,599 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:28,226 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:29,456 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:30,416 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:31,505 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:32,324 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:33,917 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:34,961 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:35,812 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:36,638 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:37,543 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:38,383 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:39,139 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:40,078 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:40,856 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:41,864 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:43,047 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:44,135 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:44,928 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:45,840 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:47,889 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:48,891 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:50,198 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:51,140 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:51,804 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:52,464 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:53,292 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:54,133 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:54,867 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:55,655 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:56,654 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:57,409 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:58,337 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:41:59,138 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:00,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:00,783 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:01,593 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:02,780 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:03,866 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:04,798 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:05,809 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:06,627 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:08,063 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:08,070 - past_reference_detector - INFO - Completed batch 1 with 50 prompts
# Batch 2:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:42:08,909 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:09,683 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:10,729 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:11,439 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:12,880 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:14,111 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:15,558 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:16,575 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:17,684 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:18,608 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:19,636 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:20,870 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:21,902 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:22,824 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:23,489 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:24,259 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:25,441 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:26,290 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:27,088 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:28,267 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:28,889 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:29,577 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:30,594 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:31,307 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:32,382 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:33,456 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:34,312 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:35,160 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:36,017 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:36,845 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:37,776 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:38,775 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:39,534 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:40,428 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:41,451 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:42,826 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:43,641 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:44,421 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:45,348 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:46,158 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:47,350 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:48,134 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:49,025 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:49,749 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:51,383 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:52,835 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:53,848 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:54,964 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:56,277 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:57,572 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:57,577 - past_reference_detector - INFO - Completed batch 2 with 50 prompts
# Batch 3:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:42:58,887 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:42:59,926 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:00,722 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:01,730 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:02,817 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:03,664 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:04,492 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:05,486 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:06,338 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:07,266 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:08,285 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:09,029 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:10,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:10,912 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:11,759 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:12,479 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:13,908 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:14,816 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:16,569 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:17,500 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:18,249 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:19,638 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:20,584 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:21,485 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:22,308 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:23,149 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:23,941 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:24,690 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:25,682 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:26,807 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:27,730 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:28,581 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:29,452 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:30,293 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:31,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:31,866 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:32,634 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:33,514 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:34,508 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:35,309 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:36,418 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:37,151 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:38,108 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:39,345 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:40,221 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:40,943 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:41,736 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:42,541 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:43,481 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:44,338 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:44,344 - past_reference_detector - INFO - Completed batch 3 with 50 prompts
# Batch 4:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:43:45,669 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:46,471 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:47,393 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:48,345 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:49,132 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:49,963 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:51,354 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:52,238 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:53,136 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:54,051 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:55,155 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:55,992 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:56,734 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:57,733 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:58,659 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:43:59,954 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:00,867 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:02,164 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:03,267 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:05,430 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:07,062 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:09,032 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:10,292 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:11,259 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:12,070 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:13,303 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:14,223 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:14,374 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:44:14,377 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 1s...
# 2025-05-07 12:44:15,559 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:44:15,561 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 2s...
# 2025-05-07 12:44:17,742 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:44:17,745 - past_reference_detector - ERROR - Failed after 3 attempts: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}
# 2025-05-07 12:44:19,057 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:20,340 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:21,559 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:22,823 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:23,987 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:25,701 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:26,566 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:27,658 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:29,063 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:30,052 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:31,020 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:32,185 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:33,182 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:34,246 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:35,568 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:37,276 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:39,291 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:41,322 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:42,612 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:43,526 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:44,487 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:45,785 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:45,795 - past_reference_detector - INFO - Completed batch 4 with 50 prompts
# Batch 5:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:44:46,816 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:48,364 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:49,291 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:50,199 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:51,425 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:52,654 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:53,882 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:55,335 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:56,336 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:57,196 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:58,080 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:59,038 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:44:59,818 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:00,743 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:01,889 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:02,937 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:03,816 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:04,666 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:05,617 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:07,328 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:08,350 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:09,179 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:11,173 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:11,332 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:45:11,334 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 1s...
# 2025-05-07 12:45:12,485 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:45:12,487 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 2s...
# 2025-05-07 12:45:14,637 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:45:14,640 - past_reference_detector - ERROR - Failed after 3 attempts: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}
# 2025-05-07 12:45:15,598 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:16,397 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:17,270 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:19,346 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:20,075 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:21,070 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:23,264 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:25,000 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:26,519 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:27,518 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:29,315 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:31,066 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:32,401 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:33,297 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:34,213 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:35,099 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:35,881 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:37,560 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:38,659 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:39,838 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:40,877 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:41,608 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:42,456 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:43,448 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:44,690 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:45,512 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:45,520 - past_reference_detector - INFO - Completed batch 5 with 50 prompts
# Batch 6:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:45:46,717 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:47,653 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:48,784 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:49,918 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:51,010 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:52,383 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:53,223 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:55,336 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:55,987 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:56,883 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:57,596 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:45:57,766 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:45:57,768 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 1s...
# 2025-05-07 12:45:58,925 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:45:58,927 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 2s...
# 2025-05-07 12:46:01,107 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-07 12:46:01,109 - past_reference_detector - ERROR - Failed after 3 attempts: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}
# 2025-05-07 12:46:02,727 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:03,462 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:04,408 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:05,374 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:06,706 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:07,734 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:08,720 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:09,881 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:10,601 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:11,630 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:12,656 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:13,465 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:14,590 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:15,548 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:16,433 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:17,558 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:18,208 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:18,889 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:19,868 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:20,740 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:21,559 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:22,488 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:23,538 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:24,619 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:25,482 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:26,479 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:27,294 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:28,266 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:29,286 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:29,957 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:30,778 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:31,535 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:32,475 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:33,137 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:33,939 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:34,717 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:35,747 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:36,820 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:36,825 - past_reference_detector - INFO - Completed batch 6 with 50 prompts
# Batch 7:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-07 12:46:37,690 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:38,593 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:39,588 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:40,799 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:41,677 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:42,643 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:43,573 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:44,433 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:45,215 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:46,025 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:47,259 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:48,379 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:49,514 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:50,696 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:51,682 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:52,504 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:53,162 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:54,320 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:55,056 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:56,166 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:57,324 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:58,224 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:46:59,008 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:00,272 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:01,297 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:02,412 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:03,705 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:05,382 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-07 12:47:06,960 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# ...
# 2025-05-08 10:35:56,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:35:56,941 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:35:57,745 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:35:58,457 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:35:59,813 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:00,616 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:01,939 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:01,958 - past_reference_detector - INFO - Completed batch 984 with 50 prompts
# Batch 985:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-08 10:36:02,820 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:03,991 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:04,830 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:06,005 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:06,670 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:07,478 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:08,396 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:09,215 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:10,144 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:11,070 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:12,002 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:13,843 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:14,854 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:15,784 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:16,672 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:18,432 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:19,455 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:20,289 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:21,526 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:22,433 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:23,659 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:24,578 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:25,451 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:26,933 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:27,743 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:28,466 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:29,207 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:30,004 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:30,847 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:31,959 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:32,759 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:33,597 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:34,716 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:35,682 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:36,557 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:37,486 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:38,825 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:40,556 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:41,369 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:42,324 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:44,035 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:44,869 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:45,797 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:46,695 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:48,044 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:49,278 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:50,341 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:51,104 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:52,128 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:53,458 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:53,464 - past_reference_detector - INFO - Completed batch 985 with 50 prompts
# Batch 986:   0%|          | 0/50 [00:00<?, ?it/s]
# 2025-05-08 10:36:54,500 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:55,518 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:56,225 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:57,256 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:58,272 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:36:59,287 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:00,103 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:00,897 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:01,650 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:02,549 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:03,702 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:04,717 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:05,637 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:05,789 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-08 10:37:05,790 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 1s...
# 2025-05-08 10:37:06,944 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-08 10:37:06,945 - past_reference_detector - WARNING - Error on prompt: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}. Retrying in 2s...
# 2025-05-08 10:37:09,121 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 400 Bad Request"
# 2025-05-08 10:37:09,121 - past_reference_detector - ERROR - Failed after 3 attempts: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.0.content: Input should be a valid list'}}
# 2025-05-08 10:37:09,946 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:10,760 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:11,684 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:12,645 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:13,333 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:14,411 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:15,374 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:16,394 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:18,235 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:19,023 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:20,079 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:21,211 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:21,946 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:22,947 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:23,665 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:24,486 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:25,403 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:26,428 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:27,243 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:28,205 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:29,092 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:30,945 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:32,166 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:32,979 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:34,006 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:34,727 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:35,752 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:36,611 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:37,696 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:38,617 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:39,444 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:40,258 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:41,381 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:42,305 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:43,126 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:44,150 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:44,161 - past_reference_detector - INFO - Completed batch 986 with 50 prompts
# Batch 987:   0%|          | 0/18 [00:00<?, ?it/s]
# 2025-05-08 10:37:45,399 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:46,089 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:47,111 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:48,444 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:49,304 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:50,402 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:51,218 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:52,047 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:52,960 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:54,334 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:55,312 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:56,127 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:57,153 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:58,096 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:37:59,440 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:38:00,322 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:38:01,937 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:38:02,893 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-05-08 10:38:02,901 - past_reference_detector - INFO - Completed batch 987 with 18 prompts

# %% [markdown]
# ## Combine results and generate report

# %%
# Combine results and generate report
# Read all batch results
all_batches = []
for filename in os.listdir("results"):
    if filename.startswith("batch_") and filename.endswith("_results.csv"):
        try:
            batch_df = pd.read_csv(f"results/{filename}")
            all_batches.append(batch_df)
        except Exception as e:
            logger.error(f"Error reading {filename}: {e}")

# Combine all results
if all_batches:
    final_df = pd.concat(all_batches, ignore_index=True)
    final_df.to_csv("results/past_references_complete_results.csv", index=False)
    print(f"Combined results from {len(all_batches)} batches, total {len(final_df)} prompts")
    
    # Generate summary statistics
    past_references_count = sum(final_df['references_past'] == 'yes')
    error_count = sum(final_df['references_past'] == 'error')
    
    print("\n--- SUMMARY STATISTICS ---")
    print(f"Total prompts processed: {len(final_df)}")
    print(f"Prompts with past references: {past_references_count} ({past_references_count/len(final_df)*100:.2f}%)")
    print(f"Prompts with errors: {error_count} ({error_count/len(final_df)*100:.2f}%)")
    
    # Display a sample of prompts with past references
    print("\n--- SAMPLE PROMPTS WITH PAST REFERENCES ---")
    past_refs = final_df[final_df['references_past'] == 'yes'].sample(min(5, past_references_count))
    display(past_refs)
else:
    print("No batch results found")
# Out:
# Combined results from 988 batches, total 49368 prompts
#
# --- SUMMARY STATISTICS ---
# Total prompts processed: 49368
# Prompts with past references: 4675 (9.47%)
# Prompts with errors: 479 (0.97%)
#
# --- SAMPLE PROMPTS WITH PAST REFERENCES ---
#                                                   prompt references_past
# 36603  film still from a sci fi movie made in 2022, s...             yes
# 15767                centaur and nymph by Reinhold Begas             yes
# 19000  film still of nixons head in a jar in the new ...             yes
# 24392  9 0 s cd album cover, four boring kids from th...             yes
# 24554  Battle between Lord Rama vs Ravana from Indian...             yes

# %% [markdown]
# ## Visualization and analysis

# %%
# Visualization and analysis
import matplotlib.pyplot as plt
import seaborn as sns

# Set a nicer style
sns.set(style="whitegrid")

# Create a pie chart
plt.figure(figsize=(10, 6))
counts = final_df['references_past'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("Set2"))
plt.axis('equal')
plt.title('Distribution of Prompts with Past References')
plt.show()

# Optionally, if your dataset has other columns (e.g., prompt length, category, etc.)
# You can do more analysis to look for patterns

# Add a prompt length column
final_df['prompt_length'] = final_df['prompt'].str.len()

# Plot prompt length distribution by reference type
plt.figure(figsize=(12, 6))
sns.histplot(data=final_df, x='prompt_length', hue='references_past', multiple='stack', bins=30)
plt.title('Prompt Length Distribution by Reference Type')
plt.xlabel('Prompt Length (characters)')
plt.ylabel('Count')
plt.show()

# Any additional analysis you might want to perform
